# %%
import pandas as pd
df = pd.read_csv("Sales_Data.csv")

# %%
df
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
#             1. Data Exploration: (All)

# 1. Load the given dataset into a DataFrame.
dm= pd.DataFrame(df)
dm
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
# 2. Display the first 5 and last 5 rows of the dataset.
dm.head()
# Out:
#    Order ID        Date     Product     Category  Quantity  Price  Total Sales
# 0         1  2024-02-21  Smartphone  Electronics         3    200          600
# 1         2  2024-04-02      Laptop  Electronics         2    100          200
# 2         3  2024-01-15  Headphones  Electronics         3    500         1500
# 3         4  2024-03-12  Headphones  Accessories         2    800         1600
# 4         5  2024-03-01  Headphones  Electronics         2    100          200

# %%
dm.tail()
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 95          400
# 96          300
# 97         1000
# 98          800
# 99          400

# %%
# 3. Check the shape of the dataset (rows and columns).
dm.shape
# Out:
# (100, 7)

# %%
# 4. List the column names and data types of the dataset.
dm.dtypes
# Out:
# Order ID        int64
# Date           object
# Product        object
# Category       object
# Quantity        int64
# Price           int64
# Total Sales     int64
# dtype: object

# %%
# 5. Check for missing values in the dataset and count them.
dm.isnull().sum().sum()
# Out:
# 0

# %%
# 6. Display summary statistics (mean, median, std, etc.) for the numerical columns.
dm["Total Sales"] = pd.to_numeric(dm["Total Sales"], errors="coerce")
dm["Total Sales"].mean()
# Out:
# 855.0

# %%
dm["Total Sales"].median()
# Out:
# 600.0

# %%
dm["Total Sales"].std()
# Out:
# 758.9699292695025

# %%
dm["Total Sales"].value_counts()
# Out:
# Total Sales
# 200     15
# 400     14
# 600      8
# 500      8
# 300      8
# 800      8
# 1000     7
# 1600     6
# 1500     5
# 2000     5
# 100      4
# 900      4
# 3200     4
# 2400     3
# 1200     1
# Name: count, dtype: int64

# %%
# 7. Identify any duplicate rows in the dataset and remove them.
dm[dm.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Category, Quantity, Price, Total Sales]
# Index: []

# %%
dm = dm.drop_duplicates()

# %%
dm.duplicated().sum()
# Out:
# 0

# %%
# 8. Get the number of unique values in each column.
dm.nunique()
# Out:
# Order ID       100
# Date            61
# Product          5
# Category         2
# Quantity         4
# Price            5
# Total Sales     15
# dtype: int64

# %%
                            #  Data Cleaning: (Any 5)
# 1. Fill any missing values in numerical columns with the mean of the respective column.
dm1= dm["Total Sales"].fillna(df["Total Sales"].mean())
dm1.isnull().sum()
# Out:
# 0

# %%
# 2. Drop rows with any missing values.
dm2= dm.dropna()
dm2
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
dm
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
# 3. Replace all occurrences of a specific value in a column (e.g., replace 'NA' with NaN).
dm3= dm["Total Sales"].replace({200:150})
dm3
# Out:
# 0      600
# 1      150
# 2     1500
# 3     1600
# 4      150
#       ...
# 95     400
# 96     300
# 97    1000
# 98     800
# 99     400
# Name: Total Sales, Length: 100, dtype: int64

# %%
# 4. Remove a specific column from the dataset.
dm4= dm.drop(columns=["Date"])
dm4
# Out:
#     Order ID     Product     Category  Quantity  Price  Total Sales
# 0          1  Smartphone  Electronics         3    200          600
# 1          2      Laptop  Electronics         2    100          200
# 2          3  Headphones  Electronics         3    500         1500
# 3          4  Headphones  Accessories         2    800         1600
# 4          5  Headphones  Electronics         2    100          200
# ..       ...         ...          ...       ...    ...          ...
# 95        96      Laptop  Electronics         2    200          400
# 96        97      Laptop  Electronics         3    100          300
# 97        98  Smartphone  Electronics         2    500         1000
# 98        99  Headphones  Accessories         1    800          800
# 99       100  Headphones  Electronics         4    100          400
#
# [100 rows x 6 columns]

# %%
# 5. Rename a column from old_name to new_name.
df.rename(columns= {"Product":"Product Name"})
# Out:
#     Order ID        Date Product Name     Category  Quantity  Price  \
# 0          1  2024-02-21   Smartphone  Electronics         3    200
# 1          2  2024-04-02       Laptop  Electronics         2    100
# 2          3  2024-01-15   Headphones  Electronics         3    500
# 3          4  2024-03-12   Headphones  Accessories         2    800
# 4          5  2024-03-01   Headphones  Electronics         2    100
# ..       ...         ...          ...          ...       ...    ...
# 95        96  2024-03-25       Laptop  Electronics         2    200
# 96        97  2024-03-20       Laptop  Electronics         3    100
# 97        98  2024-03-22   Smartphone  Electronics         2    500
# 98        99  2024-02-22   Headphones  Accessories         1    800
# 99       100  2024-01-24   Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# ...

# %%
# 6. Convert a column from string format to date format.
dm5= pd.to_datetime(df["Date"])
dm5
# Out:
# 0    2024-02-21
# 1    2024-04-02
# 2    2024-01-15
# 3    2024-03-12
# 4    2024-03-01
#         ...
# 95   2024-03-25
# 96   2024-03-20
# 97   2024-03-22
# 98   2024-02-22
# 99   2024-01-24
# Name: Date, Length: 100, dtype: datetime64[ns]

# %%
# 7. Normalize a numerical column to scale the values between 0 and 1.
dm6 = (dm["Total Sales"] - dm["Total Sales"].min()) / (df["Total Sales"].max() - df["Total Sales"].min())
dm6
# Out:
# 0     0.161290
# 1     0.032258
# 2     0.451613
# 3     0.483871
# 4     0.032258
#         ...
# 95    0.096774
# 96    0.064516
# 97    0.290323
# 98    0.225806
# 99    0.096774
# Name: Total Sales, Length: 100, dtype: float64

# %%
#                 Data Selection and Filtering: (All) 
# 1. Select the category column from the DataFrame. 
dm["Category"]
# Out:
# 0     Electronics
# 1     Electronics
# 2     Electronics
# 3     Accessories
# 4     Electronics
#          ...
# 95    Electronics
# 96    Electronics
# 97    Electronics
# 98    Accessories
# 99    Electronics
# Name: Category, Length: 100, dtype: object

# %%
# 2. Select the Reviewer and Review columns from the DataFrame. 
dm[["Product","Quantity"]]
# Out:
#        Product  Quantity
# 0   Smartphone         3
# 1       Laptop         2
# 2   Headphones         3
# 3   Headphones         2
# 4   Headphones         2
# ..         ...       ...
# 95      Laptop         2
# 96      Laptop         3
# 97  Smartphone         2
# 98  Headphones         1
# 99  Headphones         4
#
# [100 rows x 2 columns]

# %%
# 3. Filter the DataFrame to show rows where the total sales is greater than 300. 
dm[dm["Total Sales"]>300]
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 5          6  2024-01-21  Smartwatch  Electronics         2    200
# 7          8  2024-03-27  Smartwatch  Electronics         2    800
# ..       ...         ...         ...          ...       ...    ...
# 94        95  2024-02-09  Headphones  Accessories         3    200
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 2          1500
# 3          1600
# 5           400
# 7          1600
# ..          ...
# 94          600
# 95          400
# ...

# %%
# 4. Filter the dataset to display only rows where the Product is "Headphone".
dm[dm["Product"]=="Headphones"]
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# 13        14  2024-01-03  Headphones  Electronics         3    300
# 25        26  2024-03-16  Headphones  Electronics         4    800
# 27        28  2024-01-22  Headphones  Electronics         4    100
# 32        33  2024-02-11  Headphones  Electronics         1    200
# 46        47  2024-01-07  Headphones  Electronics         1    200
# 50        51  2024-01-18  Headphones  Electronics         3    100
# 52        53  2024-03-29  Headphones  Electronics         1    800
# 57        58  2024-02-22  Headphones  Accessories         4    800
# 61        62  2024-02-29  Headphones  Electronics         3    200
# 67        68  2024-03-18  Headphones  Electronics         2    300
# ...

# %%
#                     Sorting and Ordering: (All) 
# 1. Sort the DataFrame by Total sales in ascending order. 
dm7= dm.sort_values("Total Sales", ascending = True)
dm7
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 38        39  2024-03-02      Tablet  Electronics         1    100
# 43        44  2024-03-04      Laptop  Electronics         1    100
# 8          9  2024-03-15  Smartwatch  Electronics         1    100
# 86        87  2024-01-14      Laptop  Electronics         1    100
# 65        66  2024-02-16      Laptop  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 49        50  2024-02-08      Laptop  Electronics         3    800
# 60        61  2024-04-01      Tablet  Electronics         4    800
# 41        42  2024-02-20  Smartphone  Accessories         4    800
# 25        26  2024-03-16  Headphones  Electronics         4    800
# 57        58  2024-02-22  Headphones  Accessories         4    800
#
#     Total Sales
# 38          100
# 43          100
# 8           100
# 86          100
# 65          200
# ..          ...
# 49         2400
# 60         3200
# ...

# %%
# 2. Sort the column alphabetically (for example, product). 
dm8= dm.sort_values(by=["Product","Category"], ascending= [True,True])
dm8
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 57        58  2024-02-22  Headphones  Accessories         4    800
# 71        72  2024-01-04  Headphones  Accessories         2    100
# 91        92  2024-03-18  Headphones  Accessories         3    300
# 94        95  2024-02-09  Headphones  Accessories         3    200
# ..       ...         ...         ...          ...       ...    ...
# 72        73  2024-01-02      Tablet  Electronics         4    200
# 79        80  2024-01-18      Tablet  Electronics         3    200
# 84        85  2024-03-02      Tablet  Electronics         1    500
# 85        86  2024-04-09      Tablet  Electronics         4    200
# 92        93  2024-03-27      Tablet  Electronics         1    500
#
#     Total Sales
# 3          1600
# 57         3200
# 71          200
# 91          900
# 94          600
# ..          ...
# 72          800
# 79          600
# ...

# %%
# 3. Sort the column in descending order (for example, Product). 
dm9= dm.sort_values(by= "Product", ascending = False)
dm9
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 60        61  2024-04-01      Tablet  Electronics         4    800
# 55        56  2024-01-09      Tablet  Electronics         1    800
# 89        90  2024-01-15      Tablet  Accessories         2    500
# 59        60  2024-03-24      Tablet  Electronics         1    200
# 31        32  2024-02-28      Tablet  Accessories         4    100
# ..       ...         ...         ...          ...       ...    ...
# 67        68  2024-03-18  Headphones  Electronics         2    300
# 68        69  2024-03-21  Headphones  Electronics         2    200
# 69        70  2024-02-05  Headphones  Electronics         3    800
# 70        71  2024-02-19  Headphones  Electronics         4    200
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 60         3200
# 55          800
# 89         1000
# 59          200
# 31          400
# ..          ...
# 67          600
# 68          400
# ...

# %%
# 4. Sort the DataFrame by category first and then by total sales. 
dm10= dm.sort_values(by= ["Category","Total Sales"], ascending= [True,True])
dm10
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 10        11  2024-03-28      Laptop  Accessories         2    100
# 24        25  2024-02-02      Laptop  Accessories         1    200
# 36        37  2024-01-15      Tablet  Accessories         1    200
# 48        49  2024-03-13      Tablet  Accessories         1    200
# 71        72  2024-01-04  Headphones  Accessories         2    100
# ..       ...         ...         ...          ...       ...    ...
# 90        91  2024-03-12  Smartphone  Electronics         4    500
# 49        50  2024-02-08      Laptop  Electronics         3    800
# 69        70  2024-02-05  Headphones  Electronics         3    800
# 25        26  2024-03-16  Headphones  Electronics         4    800
# 60        61  2024-04-01      Tablet  Electronics         4    800
#
#     Total Sales
# 10          200
# 24          200
# 36          200
# 48          200
# 71          200
# ..          ...
# 90         2000
# 49         2400
# ...

# %%
# 5. Sort the DataFrame by total sales and keep only the Product 3 rows.
dm11= dm.sort_values(by= "Product", ascending = False).head(3)
dm11
# Out:
#     Order ID        Date Product     Category  Quantity  Price  Total Sales
# 60        61  2024-04-01  Tablet  Electronics         4    800         3200
# 55        56  2024-01-09  Tablet  Electronics         1    800          800
# 89        90  2024-01-15  Tablet  Accessories         2    500         1000

# %%
#                 Renaming Columns: (All) 
# 1. Rename the Time column to Product and Product Name. 
dm.rename(columns= {"Product":"Product Name"})
# Out:
#     Order ID        Date Product Name     Category  Quantity  Price  \
# 0          1  2024-02-21   Smartphone  Electronics         3    200
# 1          2  2024-04-02       Laptop  Electronics         2    100
# 2          3  2024-01-15   Headphones  Electronics         3    500
# 3          4  2024-03-12   Headphones  Accessories         2    800
# 4          5  2024-03-01   Headphones  Electronics         2    100
# ..       ...         ...          ...          ...       ...    ...
# 95        96  2024-03-25       Laptop  Electronics         2    200
# 96        97  2024-03-20       Laptop  Electronics         3    100
# 97        98  2024-03-22   Smartphone  Electronics         2    500
# 98        99  2024-02-22   Headphones  Accessories         1    800
# 99       100  2024-01-24   Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# ...

# %%
# 2. Rename the date column to DATE. 
dm.rename(columns= {"Date":"DATE"})
# Out:
#     Order ID        DATE     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
# 3. Rename multiple columns at once (e.g., date to DATE and Product to Product Name). 
dm20 = dm
dm20= dm.rename(columns= {"Date":"DATE","Product":"Product Name"})
dm20
# Out:
#     Order ID        DATE Product Name     Category  Quantity  Price  \
# 0          1  2024-02-21   Smartphone  Electronics         3    200
# 1          2  2024-04-02       Laptop  Electronics         2    100
# 2          3  2024-01-15   Headphones  Electronics         3    500
# 3          4  2024-03-12   Headphones  Accessories         2    800
# 4          5  2024-03-01   Headphones  Electronics         2    100
# ..       ...         ...          ...          ...       ...    ...
# 95        96  2024-03-25       Laptop  Electronics         2    200
# 96        97  2024-03-20       Laptop  Electronics         3    100
# 97        98  2024-03-22   Smartphone  Electronics         2    500
# 98        99  2024-02-22   Headphones  Accessories         1    800
# 99       100  2024-01-24   Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# ...

# %%
# 4. Change the column name to a simpler one (e.g., Product Name to product). 
dm20.rename(columns= {"Product Name":"Product"})
# Out:
#     Order ID        DATE     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
#                 Data Aggregation: (Any 5) 
# 1. Find the average of the Pictures column. 
pd.to_numeric(dm["Quantity"]).mean()
# Out:
# 2.45

# %%
# 2. Find the total sum of the Pictures column. 
dm["Quantity"].sum()
# Out:
# 245

# %%
# 3. Count how many times each value appears in the Restaurant column. 
dm["Total Sales"].value_counts()
# Out:
# Total Sales
# 200     15
# 400     14
# 600      8
# 500      8
# 300      8
# 800      8
# 1000     7
# 1600     6
# 1500     5
# 2000     5
# 100      4
# 900      4
# 3200     4
# 2400     3
# 1200     1
# Name: count, dtype: int64

# %%
# 4. Calculate the total sum of total sales for each unique value in the product column. 
dm.groupby("Product")["Total Sales"].sum()
# Out:
# Product
# Headphones    22200
# Laptop        20200
# Smartphone    13100
# Smartwatch    13800
# Tablet        16200
# Name: Total Sales, dtype: int64

# %%
# 5. Find the highest Quantity in the dataset. 
dm["Quantity"].max()
# Out:
# 4

# %%
# 6. Calculate the minimum quantity in the dataset.
df["Quantity"].min()
# Out:
# 1

# %%
df["Total Sales"].unique()[0:5]
# Out:
# array([ 600,  200, 1500, 1600,  400], dtype=int64)

# %%
import matplotlib.pyplot as plt

# Calculate average sales per product
avg_sales = df.groupby("Product")["Total Sales"].mean().head(5)

# Plot bar chart
plt.figure(figsize=(8, 5))
plt.bar(avg_sales.index, avg_sales.values, color='skyblue')

# Labels and title
plt.xlabel("Product")
plt.ylabel("Average Sales")
plt.title("Average Sales per Product")
plt.xticks(rotation=45)
plt.show()

# %%
vg_sales = df.groupby("Product")["Total Sales"].mean()

# Sort values for a better line plot
avg_sales = avg_sales.sort_values()

# Plot line chart
plt.figure(figsize=(10, 5))
plt.plot(avg_sales.index, avg_sales.values, marker="o", linestyle="-", color="blue")

# Labels and title
plt.xlabel("Product")
plt.ylabel("Average Sales")
plt.title("Average Sales per Product")
plt.xticks(rotation=45)
plt.grid(True)

# Show plot
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df["Total Sales"], bins=10, color="skyblue", edgecolor="black")
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.title("Distribution of Total Sales")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
sales_distribution = df.groupby("Product")["Total Sales"].sum().nlargest(5)
plt.figure(figsize=(8, 8))
plt.pie(sales_distribution, labels=sales_distribution.index, autopct="%1.1f%%", startangle=0, colors=plt.cm.Paired.colors)
plt.title("Sales Distribution by Top 5 Products")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["Price"], df["Total Sales"], color="blue", alpha=0.5)
plt.xlabel("Price")
plt.ylabel("Total Sales")
plt.title("Scatter Plot: Price vs. Total Sales")
plt.show()

# %%
plt.boxplot(dm["Total Sales"], vert=False, patch_artist=True)
plt.show()

# %%
dm
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
#                 Basic String Manipulation: (All) 
# 1. Convert the Product column values to lowercase. 
dm["Product"].str.lower()
# Out:
# 0     smartphone
# 1         laptop
# 2     headphones
# 3     headphones
# 4     headphones
#          ...
# 95        laptop
# 96        laptop
# 97    smartphone
# 98    headphones
# 99    headphones
# Name: Product, Length: 100, dtype: object

# %%
# 2. Extract the first 4 characters of the Product column. 
dm["Product"].str[:4]
# Out:
# 0     Smar
# 1     Lapt
# 2     Head
# 3     Head
# 4     Head
#       ...
# 95    Lapt
# 96    Lapt
# 97    Smar
# 98    Head
# 99    Head
# Name: Product, Length: 100, dtype: object

# %%
# 3. Split the  product column into two columns: First_Name. 
dmcopy = dm.copy()
dmcopy[["First_Name"]]=dmcopy["Product"].str.split(" ",n=1,expand = True)
dmcopy["First_Name"].fillna("")
dmcopy = dmcopy.drop(columns=["Product"])
dmcopy
# Out:
#     Order ID        Date     Category  Quantity  Price  Total Sales  \
# 0          1  2024-02-21  Electronics         3    200          600
# 1          2  2024-04-02  Electronics         2    100          200
# 2          3  2024-01-15  Electronics         3    500         1500
# 3          4  2024-03-12  Accessories         2    800         1600
# 4          5  2024-03-01  Electronics         2    100          200
# ..       ...         ...          ...       ...    ...          ...
# 95        96  2024-03-25  Electronics         2    200          400
# 96        97  2024-03-20  Electronics         3    100          300
# 97        98  2024-03-22  Electronics         2    500         1000
# 98        99  2024-02-22  Accessories         1    800          800
# 99       100  2024-01-24  Electronics         4    100          400
#
#     First_Name
# 0   Smartphone
# 1       Laptop
# 2   Headphones
# 3   Headphones
# 4   Headphones
# ..         ...
# 95      Laptop
# 96      Laptop
# ...

# %%
# 4. Concatenate the First_Name into a new column product. 
dmcopy["Product"] = dmcopy["First_Name"] 
dmcopy = dmcopy.drop(columns=['First_Name'])
dmcopy
# Out:
#     Order ID        Date     Category  Quantity  Price  Total Sales  \
# 0          1  2024-02-21  Electronics         3    200          600
# 1          2  2024-04-02  Electronics         2    100          200
# 2          3  2024-01-15  Electronics         3    500         1500
# 3          4  2024-03-12  Accessories         2    800         1600
# 4          5  2024-03-01  Electronics         2    100          200
# ..       ...         ...          ...       ...    ...          ...
# 95        96  2024-03-25  Electronics         2    200          400
# 96        97  2024-03-20  Electronics         3    100          300
# 97        98  2024-03-22  Electronics         2    500         1000
# 98        99  2024-02-22  Accessories         1    800          800
# 99       100  2024-01-24  Electronics         4    100          400
#
#        Product
# 0   Smartphone
# 1       Laptop
# 2   Headphones
# 3   Headphones
# 4   Headphones
# ..         ...
# 95      Laptop
# 96      Laptop
# ...

# %%
# 5. Replace all spaces in the Reviewer column with underscores. 
df["Product"].str.replace(" ", "_")
# Out:
# 0     Smartphone
# 1         Laptop
# 2     Headphones
# 3     Headphones
# 4     Headphones
#          ...
# 95        Laptop
# 96        Laptop
# 97    Smartphone
# 98    Headphones
# 99    Headphones
# Name: Product, Length: 100, dtype: object

# %%
#                 iloc - Integer-location based indexing: (Any 5) 
# 1. Select the first row of the dataset using iloc. 
dm.iloc[:1]
# Out:
#    Order ID        Date     Product     Category  Quantity  Price  Total Sales
# 0         1  2024-02-21  Smartphone  Electronics         3    200          600

# %%
# 2. Select the last 3 rows of the dataset using iloc. 
dm.iloc[-3:]
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 97         1000
# 98          800
# 99          400

# %%
# 3. Select the first 5 rows and the first 3 columns using iloc. 
dm.iloc[:5,:3]
# Out:
#    Order ID        Date     Product
# 0         1  2024-02-21  Smartphone
# 1         2  2024-04-02      Laptop
# 2         3  2024-01-15  Headphones
# 3         4  2024-03-12  Headphones
# 4         5  2024-03-01  Headphones

# %%
# 4. Select all rows of the dataset but only the 2nd and 3rd columns using iloc. 
dm.iloc[:,[1,2]]
# Out:
#           Date     Product
# 0   2024-02-21  Smartphone
# 1   2024-04-02      Laptop
# 2   2024-01-15  Headphones
# 3   2024-03-12  Headphones
# 4   2024-03-01  Headphones
# ..         ...         ...
# 95  2024-03-25      Laptop
# 96  2024-03-20      Laptop
# 97  2024-03-22  Smartphone
# 98  2024-02-22  Headphones
# 99  2024-01-24  Headphones
#
# [100 rows x 2 columns]

# %%
# 5. Select the value at the 4th row and 2nd column using iloc. 
dm.iloc[3,2]
# Out:
# 'Headphones'

# %%
# 6. Use iloc to select rows 2 to 5 and columns 1 to 4. 
dm.iloc[1:5,:4]
# Out:
#    Order ID        Date     Product     Category
# 1         2  2024-04-02      Laptop  Electronics
# 2         3  2024-01-15  Headphones  Electronics
# 3         4  2024-03-12  Headphones  Accessories
# 4         5  2024-03-01  Headphones  Electronics

# %%
#                 loc - Label-based indexing: (Any 5) 
# 1. Select the row where the product is "headphones" using loc. 
df.loc[df["Product"]=="Headphones"]
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# 13        14  2024-01-03  Headphones  Electronics         3    300
# 25        26  2024-03-16  Headphones  Electronics         4    800
# 27        28  2024-01-22  Headphones  Electronics         4    100
# 32        33  2024-02-11  Headphones  Electronics         1    200
# 46        47  2024-01-07  Headphones  Electronics         1    200
# 50        51  2024-01-18  Headphones  Electronics         3    100
# 52        53  2024-03-29  Headphones  Electronics         1    800
# 57        58  2024-02-22  Headphones  Accessories         4    800
# 61        62  2024-02-29  Headphones  Electronics         3    200
# 67        68  2024-03-18  Headphones  Electronics         2    300
# ...

# %%
# 2. Select rows where the Quantity is greater than 2 using loc. 
dm.loc[df["Quantity"]>2]
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 9         10  2024-03-15      Laptop  Electronics         3    300
# 11        12  2024-04-09      Laptop  Accessories         4    500
# 12        13  2024-01-24      Laptop  Electronics         3    500
# 13        14  2024-01-03  Headphones  Electronics         3    300
# 18        19  2024-01-30      Tablet  Electronics         4    500
# 19        20  2024-02-07      Laptop  Accessories         3    800
# 20        21  2024-01-02      Tablet  Electronics         4    100
# 23        24  2024-01-21  Smartphone  Accessories         4    100
# 25        26  2024-03-16  Headphones  Electronics         4    800
# 26        27  2024-02-27      Laptop  Electronics         3    200
# 27        28  2024-01-22  Headphones  Electronics         4    100
# ...

# %%
# 3. Select the City column for rows where Quantity is between 1 and 4 using loc. 
df.loc[(df["Quantity"]>1) & (df["Quantity"]<4)]
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# 5          6  2024-01-21  Smartwatch  Electronics         2    200
# 6          7  2024-03-23      Laptop  Electronics         2    100
# 7          8  2024-03-27  Smartwatch  Electronics         2    800
# 9         10  2024-03-15      Laptop  Electronics         3    300
# 10        11  2024-03-28      Laptop  Accessories         2    100
# 12        13  2024-01-24      Laptop  Electronics         3    500
# 13        14  2024-01-03  Headphones  Electronics         3    300
# 14        15  2024-01-22      Tablet  Electronics         2    800
# ...

# %%
# 4. Select all rows and columns where Product is "laptop" using loc. 
df.loc[df["Product"]=="Laptop"]
# Out:
#     Order ID        Date Product     Category  Quantity  Price  Total Sales
# 1          2  2024-04-02  Laptop  Electronics         2    100          200
# 6          7  2024-03-23  Laptop  Electronics         2    100          200
# 9         10  2024-03-15  Laptop  Electronics         3    300          900
# 10        11  2024-03-28  Laptop  Accessories         2    100          200
# 11        12  2024-04-09  Laptop  Accessories         4    500         2000
# 12        13  2024-01-24  Laptop  Electronics         3    500         1500
# 16        17  2024-01-02  Laptop  Accessories         2    200          400
# 19        20  2024-02-07  Laptop  Accessories         3    800         2400
# 24        25  2024-02-02  Laptop  Accessories         1    200          200
# 26        27  2024-02-27  Laptop  Electronics         3    200          600
# 29        30  2024-02-18  Laptop  Accessories         4    100          400
# ...

# %%
# 5. Select multiple columns (product, quantity) for a specific row with loc. 
dm.loc[:0,["Product","Quantity"]]
# Out:
#       Product  Quantity
# 0  Smartphone         3

# %%
# 6. Use loc to select the row where total sales is greater than 200 and the product is "laptop".
dm.loc[(dm["Total Sales"]>200)&(dm["Product"]=="Laptop")]
# Out:
#     Order ID        Date Product     Category  Quantity  Price  Total Sales
# 9         10  2024-03-15  Laptop  Electronics         3    300          900
# 11        12  2024-04-09  Laptop  Accessories         4    500         2000
# 12        13  2024-01-24  Laptop  Electronics         3    500         1500
# 16        17  2024-01-02  Laptop  Accessories         2    200          400
# 19        20  2024-02-07  Laptop  Accessories         3    800         2400
# 26        27  2024-02-27  Laptop  Electronics         3    200          600
# 29        30  2024-02-18  Laptop  Accessories         4    100          400
# 39        40  2024-02-16  Laptop  Electronics         2    500         1000
# 49        50  2024-02-08  Laptop  Electronics         3    800         2400
# 75        76  2024-01-04  Laptop  Electronics         3    200          600
# 77        78  2024-04-02  Laptop  Accessories         3    500         1500
# ...

# %%
#                 replace - Replacing values in a DataFrame: (Any 5) 
# 1. Replace all occurrences of the value "Laptop" with "Mac" in the Product column. 
dm["Product"].replace("Laptop","Mac")
# Out:
# 0     Smartphone
# 1            Mac
# 2     Headphones
# 3     Headphones
# 4     Headphones
#          ...
# 95           Mac
# 96           Mac
# 97    Smartphone
# 98    Headphones
# 99    Headphones
# Name: Product, Length: 100, dtype: object

# %%
# 2. Replace the value 0 with NaN in a specific numerical column. 
dm["Total Sales"].replace(0, np.nan)
# Out:
# 0      600
# 1      200
# 2     1500
# 3     1600
# 4      200
#       ...
# 95     400
# 96     300
# 97    1000
# 98     800
# 99     400
# Name: Total Sales, Length: 100, dtype: int64

# %%
# 3. Replace a value in the entire DataFrame. 
dm["Quantity"].replace(2,1)
# Out:
# 0     3
# 1     1
# 2     3
# 3     1
# 4     1
#      ..
# 95    1
# 96    3
# 97    1
# 98    1
# 99    4
# Name: Quantity, Length: 100, dtype: int64

# %%
# 4. Replace all occurrences of "headphones" with 1 and "laptop" with 0 in the Gender column. 
dm["Product"].replace({"Headphones":1,"Laptop":2})
# Out:
# 0     Smartphone
# 1              2
# 2              1
# 3              1
# 4              1
#          ...
# 95             2
# 96             2
# 97    Smartphone
# 98             1
# 99             1
# Name: Product, Length: 100, dtype: object

# %%
# 5. Replace multiple values
dm["Product"].replace({"Headphones":"earphones","Laptop":"Mac","Smartphone":"Mobiles"})
# Out:
# 0       Mobiles
# 1           Mac
# 2     earphones
# 3     earphones
# 4     earphones
#         ...
# 95          Mac
# 96          Mac
# 97      Mobiles
# 98    earphones
# 99    earphones
# Name: Product, Length: 100, dtype: object

# %%
# 6. Replace the value of "NA" in the Total Sales column with the mean of the column. 
dm["Total Sales"].replace(np.nan, dm["Total Sales"].mean())
# Out:
# 0      600
# 1      200
# 2     1500
# 3     1600
# 4      200
#       ...
# 95     400
# 96     300
# 97    1000
# 98     800
# 99     400
# Name: Total Sales, Length: 100, dtype: int64

# %%
#             index - Indexing and resetting index: (Any 5) 
# 1. Set a specific column (e.g., Name) as the index of the DataFrame. 
dm.set_index("Product")
# Out:
#             Order ID        Date     Category  Quantity  Price  Total Sales
# Product
# Smartphone         1  2024-02-21  Electronics         3    200          600
# Laptop             2  2024-04-02  Electronics         2    100          200
# Headphones         3  2024-01-15  Electronics         3    500         1500
# Headphones         4  2024-03-12  Accessories         2    800         1600
# Headphones         5  2024-03-01  Electronics         2    100          200
# ...              ...         ...          ...       ...    ...          ...
# Laptop            96  2024-03-25  Electronics         2    200          400
# Laptop            97  2024-03-20  Electronics         3    100          300
# Smartphone        98  2024-03-22  Electronics         2    500         1000
# Headphones        99  2024-02-22  Accessories         1    800          800
# Headphones       100  2024-01-24  Electronics         4    100          400
#
# [100 rows x 6 columns]

# %%
# 2. Reset the index of the DataFrame after setting a new column as the index. 
dm.reset_index()
# Out:
#     index  Order ID        Date     Product     Category  Quantity  Price  \
# 0       0         1  2024-02-21  Smartphone  Electronics         3    200
# 1       1         2  2024-04-02      Laptop  Electronics         2    100
# 2       2         3  2024-01-15  Headphones  Electronics         3    500
# 3       3         4  2024-03-12  Headphones  Accessories         2    800
# 4       4         5  2024-03-01  Headphones  Electronics         2    100
# ..    ...       ...         ...         ...          ...       ...    ...
# 95     95        96  2024-03-25      Laptop  Electronics         2    200
# 96     96        97  2024-03-20      Laptop  Electronics         3    100
# 97     97        98  2024-03-22  Smartphone  Electronics         2    500
# 98     98        99  2024-02-22  Headphones  Accessories         1    800
# 99     99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# ...

# %%
# 3. Set a multi-level index using Restaurant and Rating columns. 
dmindex= dm.set_index(["Product","Category"])
dmindex
# Out:
#                         Order ID        Date  Quantity  Price  Total Sales
# Product    Category
# Smartphone Electronics         1  2024-02-21         3    200          600
# Laptop     Electronics         2  2024-04-02         2    100          200
# Headphones Electronics         3  2024-01-15         3    500         1500
#            Accessories         4  2024-03-12         2    800         1600
#            Electronics         5  2024-03-01         2    100          200
# ...                          ...         ...       ...    ...          ...
# Laptop     Electronics        96  2024-03-25         2    200          400
#            Electronics        97  2024-03-20         3    100          300
# Smartphone Electronics        98  2024-03-22         2    500         1000
# Headphones Accessories        99  2024-02-22         1    800          800
#            Electronics       100  2024-01-24         4    100          400
#
# [100 rows x 5 columns]

# %%
# 4. Access a specific row by using the index after setting the index to Product. 
dmindex.loc["Laptop"]
# Out:
#              Order ID        Date  Quantity  Price  Total Sales
# Category
# Electronics         2  2024-04-02         2    100          200
# Electronics         7  2024-03-23         2    100          200
# Electronics        10  2024-03-15         3    300          900
# Accessories        11  2024-03-28         2    100          200
# Accessories        12  2024-04-09         4    500         2000
# Electronics        13  2024-01-24         3    500         1500
# Accessories        17  2024-01-02         2    200          400
# Accessories        20  2024-02-07         3    800         2400
# Accessories        25  2024-02-02         1    200          200
# Electronics        27  2024-02-27         3    200          600
# Accessories        30  2024-02-18         4    100          400
# Electronics        36  2024-03-20         2    100          200
# Electronics        40  2024-02-16         2    500         1000
# ...

# %%
# 5. Check the index type and whether it’s unique. 
type(dmindex.index)
dmindex.index.is_unique
# Out:
# False

# %%
# 6. Rename the index labels to make them more descriptive (e.g., from numeric to "Row_1", 
# "Row_2").
dmindex.reset_index()
dmindex.index= ["Row_"+ str(i+1) for i in range(len(dmindex))]
dmindex
# Out:
#          Order ID        Date  Quantity  Price  Total Sales
# Row_1           1  2024-02-21         3    200          600
# Row_2           2  2024-04-02         2    100          200
# Row_3           3  2024-01-15         3    500         1500
# Row_4           4  2024-03-12         2    800         1600
# Row_5           5  2024-03-01         2    100          200
# ...           ...         ...       ...    ...          ...
# Row_96         96  2024-03-25         2    200          400
# Row_97         97  2024-03-20         3    100          300
# Row_98         98  2024-03-22         2    500         1000
# Row_99         99  2024-02-22         1    800          800
# Row_100       100  2024-01-24         4    100          400
#
# [100 rows x 5 columns]

# %%
dm
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
#                 groupby - Grouping data: (Any 5) 
# 1. Group the dataset by product and find the average Quantity . 
dm.groupby("Product")["Quantity"].mean()
# Out:
# Product
# Headphones    2.652174
# Laptop        2.407407
# Smartphone    2.833333
# Smartwatch    2.117647
# Tablet        2.333333
# Name: Quantity, dtype: float64

# %%
# 2. Group by Quantity and get the count of each group in the product column. 
dm.groupby("Product")["Quantity"].count()
# Out:
# Product
# Headphones    23
# Laptop        27
# Smartphone    12
# Smartwatch    17
# Tablet        21
# Name: Quantity, dtype: int64

# %%
# 3. Group the data by product and calculate the Quantity for each product category. 
dm.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Headphones    61
# Laptop        65
# Smartphone    34
# Smartwatch    36
# Tablet        49
# Name: Quantity, dtype: int64

# %%
# 4. Group by product and display the sum of Total Sales for each product group. 
dm.groupby("Product")["Total Sales"].sum()
# Out:
# Product
# Headphones    22200
# Laptop        20200
# Smartphone    13100
# Smartwatch    13800
# Tablet        16200
# Name: Total Sales, dtype: int64

# %%
# 5. Group by product and find the number of unique entries in the Order ID column. 
dm.groupby("Product")["Order ID"].nunique()
# Out:
# Product
# Headphones    23
# Laptop        27
# Smartphone    12
# Smartwatch    17
# Tablet        21
# Name: Order ID, dtype: int64

# %%
# 6. Group the dataset by Product and find the maximum value of Total Sales for each group.
dm.groupby("Product")["Total Sales"].max()
# Out:
# Product
# Headphones    3200
# Laptop        2400
# Smartphone    3200
# Smartwatch    2000
# Tablet        3200
# Name: Total Sales, dtype: int64

# %%
#                 aggregation - Performing multiple aggregations: (Any 5) 
# 1. Group by Product and calculate both the mean and median of the Total Sales. 
dm.groupby("Product")["Total Sales"].mean()
# Out:
# Product
# Headphones     965.217391
# Laptop         748.148148
# Smartphone    1091.666667
# Smartwatch     811.764706
# Tablet         771.428571
# Name: Total Sales, dtype: float64

# %%
dm.groupby("Product")["Total Sales"].median()
# Out:
# Product
# Headphones    600.0
# Laptop        400.0
# Smartphone    700.0
# Smartwatch    600.0
# Tablet        500.0
# Name: Total Sales, dtype: float64

# %%
# 2. Perform multiple aggregations: find the sum, mean, and count of the total sales column, 
# grouped by product. 
dm.groupby("Product")["Total Sales"].agg(["sum","mean","count"]).reset_index()
# Out:
#       Product    sum         mean  count
# 0  Headphones  22200   965.217391     23
# 1      Laptop  20200   748.148148     27
# 2  Smartphone  13100  1091.666667     12
# 3  Smartwatch  13800   811.764706     17
# 4      Tablet  16200   771.428571     21

# %%
# 3. Group by Product and apply min() and max() functions to the Total Sales column. 
dm.groupby("Product").agg({
    "Total Sales":["min","max"]
}).reset_index()
# Out:
#       Product Total Sales
#                       min   max
# 0  Headphones         200  3200
# 1      Laptop         100  2400
# 2  Smartphone         300  3200
# 3  Smartwatch         100  2000
# 4      Tablet         100  3200

# %%
# 4. Group by product and apply a custom aggregation function (e.g., find the range of total sales
# within each product). 
dm.groupby("Product")["Total Sales"].agg(lambda x: x.max()-x.min())
# Out:
# Product
# Headphones    3000
# Laptop        2300
# Smartphone    2900
# Smartwatch    1900
# Tablet        3100
# Name: Total Sales, dtype: int64

# %%
# 5. Group by product and calculate the average price, along with the total sales for each 
# group. 
dm.groupby("Product").agg({
    "Price":"mean",
    "Total Sales":"sum"
}).reset_index()
# Out:
#       Product       Price  Total Sales
# 0  Headphones  382.608696        22200
# 1      Laptop  292.592593        20200
# 2  Smartphone  391.666667        13100
# 3  Smartwatch  382.352941        13800
# 4      Tablet  361.904762        16200

# %%
# 6. Group the data by product and find both the standard deviation and the variance of the 
# Total Sales.  
dm.groupby("Product")["Total Sales"].agg(["std","var"]).reset_index()
# Out:
#       Product         std            var
# 0  Headphones  896.766259  804189.723320
# 1      Laptop  708.394919  501823.361823
# 2  Smartphone  916.969647  840833.333333
# 3  Smartwatch  552.134894  304852.941176
# 4      Tablet  732.217766  536142.857143

# %%
#                 faker - Generating Fake Data for Testing: (All) 
# 1. Generate a fake dataset with 100 rows of random names, addresses, and dates using the 
# Faker library. 
# !pip install faker
import faker
fake= faker.Faker('en_IN')
data=[]
for _ in range(100):
    record={
        "Name": fake.name(),
        "Address": fake.address(),
        "Date": fake.date()
    }
    data.append(record)
ds= pd.DataFrame(data)
ds
# Out:
# ...
#                  Name                                      Address        Date
# 0         Hemang Nair         H.No. 487, Bala, South Dumdum-043208  2021-03-03
# 1          Jyoti Sood          95/02\nCherian Marg, Danapur-355274  1983-06-08
# 2       Devansh Arora        39/12\nKhatri Path\nBongaigaon-326592  1985-03-20
# 3         Warda Borah  H.No. 732\nChowdhury Path\nAhmedabad 325112  2006-11-28
# 4           Vanya Lad               74, Pau Marg, Panchkula-786857  1989-04-16
# ..                ...                                          ...         ...
# 95          Noah Kaur         71/29\nSarin Nagar, Nizamabad-231948  2020-10-06
# 96  Osha Mukhopadhyay              74\nPatla Chowk, Danapur 254227  1976-10-13
# 97        Edhitha Roy          H.No. 291, Bera Ganj\nIndore 667953  1989-05-13
# 98         Anita Chad     H.No. 736, Kalla Street\nBhatpara-490175  1998-01-05
# 99       Aashi Oommen        03/265, Mistry Road\nBegusarai 045578  2018-05-08
#
# [100 rows x 3 columns]

# %%
# 2. Create a list of 20 fake names and store them in a Name column. 
list= {'Name': [fake.name() for _ in range(20)]}
nameds= pd.DataFrame(list)
nameds
# Out:
#                      Name
# 0            Triveni Pall
# 1           Orinder Samra
# 2   Nachiket Venkataraman
# 3              Qadim Bala
# 4               Bina Loke
# 5           Neelima Datta
# 6              Waida Bail
# 7           Oviya Sampath
# 8              Qadim Bahl
# 9            Ekavir Patil
# 10           Kalpit Rajan
# 11          Dominic Barad
# 12           Ishaan Edwin
# 13        William Maharaj
# 14            Lucky Dutta
# 15             Nisha Dash
# 16           Gaurang Bera
# 17          Daksh Sachdev
# 18            Jason Amble
# 19          Vasudha Sidhu

# %%
# 3. Generate fake email addresses and store them in a column called Email. 
list= {'Name': [fake.address() for _ in range(20)]}
addressds= pd.DataFrame(list)
addressds
# Out:
#                                           Name
# 0       H.No. 04\nShenoy Chowk, Jodhpur 793292
# 1    H.No. 67\nChaudhry Street, Deoghar 145548
# 2           97, Manne Circle, Serampore-196558
# 3              H.No. 905, Badami, Morbi 517763
# 4    36/677, Bhardwaj Circle, Bhagalpur 479186
# 5               57/298\nJha, Kumbakonam 665754
# 6          224, Thaker Circle\nUluberia 124378
# 7               42\nBorde Zila\nHajipur 135072
# 8          79/25, Lata Path, Chandrapur-458441
# 9         850\nZachariah Marg, Kottayam 734062
# 10                    166, Ben\nAsansol 202032
# 11               22, Kamdar, Chandrapur-619216
# 12        44/45, Arora Ganj\nSaharanpur 136475
# 13  56/91, Iyengar Circle, Narasaraopet-944724
# 14           H.No. 52\nTara Zila\nPatna-476621
# 15       H.No. 028\nSen Ganj, Singrauli 506240
# 16                180\nPau Nagar\nPatna-819753
# 17           075\nSarin Marg\nBardhaman-390020
# 18       008, Mistry Street, Karimnagar-561879
# ...

# %%
# 4. Generate fake dates of birth and convert them into an Age column using Faker. 
from datetime import datetime
dob_list = [fake.date_of_birth(minimum_age=18, maximum_age=80) for _ in range(20)]
age_data = {'Date_of_Birth': dob_list, 'Age': [(datetime.today().year - dob.year) for dob in dob_list]}
dobds = pd.DataFrame(age_data)
dobds
# Out:
#    Date_of_Birth  Age
# 0     1948-02-22   77
# 1     1985-09-01   40
# 2     1974-04-21   51
# 3     2005-06-23   20
# 4     1979-11-04   46
# 5     1990-07-19   35
# 6     2002-01-05   23
# 7     1950-09-14   75
# 8     1954-11-13   71
# 9     1987-06-18   38
# 10    1984-02-11   41
# 11    1983-07-07   42
# 12    1955-04-08   70
# 13    1989-12-20   36
# 14    1962-02-10   63
# 15    1977-08-14   48
# 16    1966-07-17   59
# 17    1968-07-23   57
# 18    1964-07-17   61
# 19    1972-11-13   53

# %%
# 5. Generate fake product names, and then create a DataFrame with columns for 
# Product_Name and Price. 
import random
product_data = {
    'Product_Name': [fake.word().capitalize() for _ in range(20)],
    'Price': [round(random.uniform(10, 500), 2) for _ in range(20)]
}
prodds = pd.DataFrame(product_data)
prodds
# Out:
#    Product_Name   Price
# 0   Consequatur  262.81
# 1       Numquam   20.19
# 2    Distinctio  433.61
# 3    Voluptatem  404.40
# 4          Iste  334.52
# 5           Nam   34.78
# 6          Quam  214.56
# 7         Iusto  408.13
# 8          Odio  261.49
# 9        Labore  259.72
# 10        Ipsam  290.71
# 11        Quasi  258.84
# 12         Sint   55.85
# 13        Neque  218.38
# 14           In  271.50
# 15    Molestiae  314.55
# 16        Quasi  265.87
# 17       Soluta  278.19
# 18    Accusamus   58.47
# 19     Suscipit  143.36

# %%
# 6. Use the Faker library to create a DataFrame with fake user information, including Name, 
# City, and Phone Number. 
user_data = {
    'Name': [fake.name() for _ in range(20)],
    'City': [fake.city() for _ in range(20)],
    'Phone_Number': [fake.phone_number() for _ in range(20)]
}
userds = pd.DataFrame(user_data)
userds
# Out:
#                   Name                   City   Phone_Number
# 0      Yahvi Natarajan                  Patna  +913805348191
# 1         Indali Bains                  Thane     4103116036
# 2        Nidhi Jhaveri                 Ambala     1453096090
# 3     Vedant Venkatesh               Mirzapur  +910340719425
# 4       Patrick Pillai             Vijayawada  +917678930211
# 5          Simon Madan           South Dumdum     6541254430
# 6        Harita Mitter           Bihar Sharif     3875501576
# 7          Samarth Raj                  Dewas    06086294940
# 8            Finn Guha               Siliguri     7870082315
# 9   Ekavir Ranganathan              Ahmedabad  +919822909470
# 10        Lajita Badal             Aurangabad  +910350241998
# 11     Abhiram Kapadia           North Dumdum  +915088785513
# 12    Chandani Mahajan                Chennai    02050023290
# 13   Manbir Ramanathan  Surendranagar Dudhrej    06358008127
# ...

# %%
#                 merge - Merging DataFrames: (All) 
# 1. Merge two DataFrames on a common column Product_ID. 
df1 = pd.DataFrame({
    'Product_ID': [101, 102, 103, 104],
    'Product_Name': ['Laptop', 'Phone', 'Tablet', 'Monitor'],
    'Price': [1000, 500, 300, 200]
})

df2 = pd.DataFrame({
    'Product_ID': [102, 103, 104, 105],
    'Category': ['Electronics', 'Electronics', 'Accessories', 'Gaming'],
    'Stock': [50, 30, 20, 10]
})

pd.merge(df1, df2, on='Product_ID')
# Out:
#    Product_ID Product_Name  Price     Category  Stock
# 0         102        Phone    500  Electronics     50
# 1         103       Tablet    300  Electronics     30
# 2         104      Monitor    200  Accessories     20

# %%
# 2. Perform a left join between two DataFrames based on Employee_ID. 
df_emp1 = pd.DataFrame({
    'Employee_ID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Department': ['HR', 'IT', 'Finance', 'Marketing']
})

df_emp2 = pd.DataFrame({
    'Employee_ID': [2, 3, 5, 6],
    'Salary': [60000, 70000, 80000, 90000]
})

pd.merge(df_emp1, df_emp2, on='Employee_ID', how='left')
# Out:
#    Employee_ID     Name Department   Salary
# 0            1    Alice         HR      NaN
# 1            2      Bob         IT  60000.0
# 2            3  Charlie    Finance  70000.0
# 3            4    David  Marketing      NaN

# %%
# 3. Merge two DataFrames, keeping all rows from the left DataFrame and matching rows 
# from the right. 
pd.merge(df1, df2, on='Product_ID', how='left')
# Out:
#    Product_ID Product_Name  Price     Category  Stock
# 0         101       Laptop   1000          NaN    NaN
# 1         102        Phone    500  Electronics   50.0
# 2         103       Tablet    300  Electronics   30.0
# 3         104      Monitor    200  Accessories   20.0

# %%
# 4. Merge two DataFrames on multiple columns (e.g., City and Age). 
df_city1 = pd.DataFrame({
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
    'Age': [25, 30, 35, 40],
    'Population': [8000000, 4000000, 2700000, 2300000]
})

df_city2 = pd.DataFrame({
    'City': ['New York', 'Los Angeles', 'Chicago', 'San Francisco'],
    'Age': [25, 30, 35, 45],
    'Income': [50000, 60000, 55000, 70000]
})

pd.merge(df_city1, df_city2, on=['City', 'Age'])
# Out:
#           City  Age  Population  Income
# 0     New York   25     8000000   50000
# 1  Los Angeles   30     4000000   60000
# 2      Chicago   35     2700000   55000

# %%
# 5. Perform an inner join on two DataFrames with a common column Country. 
df_country1 = pd.DataFrame({
    'Country': ['USA', 'Canada', 'Germany', 'France'],
    'Capital': ['Washington', 'Ottawa', 'Berlin', 'Paris']
})

df_country2 = pd.DataFrame({
    'Country': ['USA', 'Canada', 'UK', 'Australia'],
    'Currency': ['USD', 'CAD', 'GBP', 'AUD']
})

pd.merge(df_country1, df_country2, on='Country', how='inner')
# Out:
#   Country     Capital Currency
# 0     USA  Washington      USD
# 1  Canada      Ottawa      CAD

# %%
# 6. Merge two DataFrames and keep all rows, even if there’s no match in the second 
# DataFrame. 
pd.merge(df1, df2, on='Product_ID', how='outer')
# Out:
#    Product_ID Product_Name   Price     Category  Stock
# 0         101       Laptop  1000.0          NaN    NaN
# 1         102        Phone   500.0  Electronics   50.0
# 2         103       Tablet   300.0  Electronics   30.0
# 3         104      Monitor   200.0  Accessories   20.0
# 4         105          NaN     NaN       Gaming   10.0

# %%
#                 Saving and Exporting Data: (All) 
# 1. Save the DataFrame to a new CSV file. 
userds.to_csv("Data.csv", index=False)

# %%
# 2. Export the DataFrame to an Excel file. 
userds.to_excel("Data.xlsx", index=False)

# %%
dm
# Out:
#     Order ID        Date     Product     Category  Quantity  Price  \
# 0          1  2024-02-21  Smartphone  Electronics         3    200
# 1          2  2024-04-02      Laptop  Electronics         2    100
# 2          3  2024-01-15  Headphones  Electronics         3    500
# 3          4  2024-03-12  Headphones  Accessories         2    800
# 4          5  2024-03-01  Headphones  Electronics         2    100
# ..       ...         ...         ...          ...       ...    ...
# 95        96  2024-03-25      Laptop  Electronics         2    200
# 96        97  2024-03-20      Laptop  Electronics         3    100
# 97        98  2024-03-22  Smartphone  Electronics         2    500
# 98        99  2024-02-22  Headphones  Accessories         1    800
# 99       100  2024-01-24  Headphones  Electronics         4    100
#
#     Total Sales
# 0           600
# 1           200
# 2          1500
# 3          1600
# 4           200
# ..          ...
# 95          400
# 96          300
# ...

# %%
#                     COMPULSORY QUESTION: 
# 1. Complex Filtering and Aggregation: 
# ● Filter the dataset for all rows where the Rating is between 0 and 4 and the Pictures is less than 10 
# ● Then, group the filtered data by Restaurant and calculate both the mean and median of the Rating column. 
# ● After that, sort the result in descending order by the Rating column. 

dataset= dm[((dm["Total Sales"]>0)&(dm["Total Sales"]<1500))& (dm["Quantity"]<10)]
dsGroup= dataset.groupby("Product")["Total Sales"].agg(["mean","median"]).reset_index()
dsGroup.sort_values(by="mean", ascending=False)
# Out:
#       Product        mean  median
# 3  Smartwatch  553.846154   500.0
# 2  Smartphone  537.500000   450.0
# 4      Tablet  522.222222   500.0
# 0  Headphones  511.764706   400.0
# 1      Laptop  419.047619   300.0

# %%
dmcopy.groupby(by="Product")["Category"].nunique()
# Out:
# Product
# Headphones    2
# Laptop        2
# Smartphone    2
# Smartwatch    2
# Tablet        2
# Name: Category, dtype: int64

# %%
product_data = pd.DataFrame({
    "Product": ["Laptop", "Headphones", "Smartphone"],
    "Price": [200, 500, 800]
})

# Make a copy of the dataset
copydf = df.copy()
copydf["Normalized Sales"] = (copydf["Total Sales"] - copydf["Total Sales"].min()) / \
                             (copydf["Total Sales"].max() - copydf["Total Sales"].min())
if "Quantity" in copydf.columns:
    median_quantity = copydf[copydf["Quantity"] >= 0]["Quantity"].median()
    copydf["Quantity"] = copydf["Quantity"].apply(lambda x: median_quantity if x < 0 else x)
merged_df = pd.merge(copydf, product_data, on="Product", how="left")
merged_df.head()
# Out:
#    Order ID        Date     Product     Category  Quantity  Price_x  \
# 0         1  2024-02-21  Smartphone  Electronics         3      200
# 1         2  2024-04-02      Laptop  Electronics         2      100
# 2         3  2024-01-15  Headphones  Electronics         3      500
# 3         4  2024-03-12  Headphones  Accessories         2      800
# 4         5  2024-03-01  Headphones  Electronics         2      100
#
#    Total Sales  Normalized Sales  Price_y
# 0          600          0.161290    800.0
# 1          200          0.032258    200.0
# 2         1500          0.451613    500.0
# 3         1600          0.483871    500.0
# 4          200          0.032258    500.0

# %%
# 1. Create a DataFrame with 'Product ID', 'Product Name', 'Quantity', and 'Price'. Add 10 
# rows of data for different products. Perform an operation to calculate the 'Total Value' 
# (Quantity * Price) and add it as a new column. Export the modified DataFrame to an 
# Excel file and compare the original and modified versions. What changes can you 
# observe in the data? 
product_data = {
    "Product ID": [fake.unique.random_int(min=1000, max=9999) for _ in range(10)],
    "Product Name": [fake.word().capitalize() for _ in range(10)],
    "Quantity": [random.randint(1, 50) for _ in range(10)],
    "Price": [round(random.uniform(10, 1000), 2) for _ in range(10)]
}

Oproddf = pd.DataFrame(product_data)
Mproddf = Oproddf.copy()
Mproddf["Total Value"] = Mproddf["Quantity"] * Mproddf["Price"]

with pd.ExcelWriter("product.xlsx") as writer:
    Oproddf.to_excel(writer, sheet_name="Original Data", index=False)
    Mproddf.to_excel(writer, sheet_name="Modified Data", index=False)

print("Original DataFrame:\n", Oproddf)
print("\nModified DataFrame with 'Total Value':\n", Mproddf)
# Out:
# Original DataFrame:
#     Product ID Product Name  Quantity   Price
# 0        8840        Atque        24  143.83
# 1        1660         Quis         2   19.56
# 2        5062        Ipsum        30  381.06
# 3        9081    Doloribus        20  264.94
# 4        1110     Voluptas         6  195.21
# 5        3296         Unde        10   77.51
# 6        8435   Aspernatur         1  871.30
# 7        9351      Numquam        21  220.59
# 8        1138  Repudiandae        26  452.39
# 9        9882     Incidunt        42  700.92
#
# Modified DataFrame with 'Total Value':
#     Product ID Product Name  Quantity   Price  Total Value
# 0        8840        Atque        24  143.83      3451.92
# 1        1660         Quis         2   19.56        39.12
# 2        5062        Ipsum        30  381.06     11431.80
# 3        9081    Doloribus        20  264.94      5298.80
# 4        1110     Voluptas         6  195.21      1171.26
# ...

# %%
# 2. Create a DataFrame with 'Student ID', 'Name', 'Grade', and 'Score'. Add 10 rows with 
# data. Perform an operation to assign a 'Pass/Fail' status based on whether the score is 
# above 50 (Pass) or below 50 (Fail). Export the modified DataFrame to an Excel file and 
# show the comparison between the initial file and the updated one. What new columns or 
# changes can you see?

student_data = {
    "Student ID": [fake.unique.random_int(min=1000, max=9999) for _ in range(10)],
    "Name": [fake.name() for _ in range(10)],
    "Grade": [random.choice(['A', 'B', 'C', 'D', 'E']) for _ in range(10)],
    "Score": [random.randint(30, 100) for _ in range(10)]  # Random scores between 30 and 100
}

original_df = pd.DataFrame(student_data)

modified_df = original_df.copy()
modified_df['Pass/Fail'] = modified_df['Score'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')

with pd.ExcelWriter("students_comparison.xlsx") as writer:
    original_df.to_excel(writer, sheet_name="Original Data", index=False)
    modified_df.to_excel(writer, sheet_name="Modified Data", index=False)

print("Original DataFrame:\n", original_df)
print("\nModified DataFrame with 'Pass/Fail' Status:\n", modified_df)
# Out:
# Original DataFrame:
#     Student ID             Name Grade  Score
# 0        5192    Ishita Shukla     D     72
# 1        3013     Yashica Sani     C     59
# 2        4989       David Kala     B     39
# 3        2722    Vrishti Boase     E     35
# 4        8251  Madhavi Chauhan     D     90
# 5        6372    Hritik Mannan     B     89
# 6        7988       Siya Arora     A     64
# 7        6612   Ayushman Memon     E     69
# 8        5573     Unnati Morar     E     34
# 9        3518    Yahvi Kothari     B     49
#
# Modified DataFrame with 'Pass/Fail' Status:
#     Student ID             Name Grade  Score Pass/Fail
# 0        5192    Ishita Shukla     D     72      Pass
# 1        3013     Yashica Sani     C     59      Pass
# 2        4989       David Kala     B     39      Fail
# 3        2722    Vrishti Boase     E     35      Fail
# 4        8251  Madhavi Chauhan     D     90      Pass
# 5        6372    Hritik Mannan     B     89      Pass
# ...

# %%
# 1. Create a CSV file and an Excel file with columns 'Student ID', 'Name', 'Grade', and 
# 'Score'. Add 5 rows of student data to each file. Upload the files to Jupyter Notebook, 
# then perform an operation to assign a 'Pass/Fail' status based on whether the score is 
# above 50. Export the modified CSV and Excel files and compare them with the originals. 
# Explain the differences and the new columns added. 

student_info = {
    "Student ID": [fake.unique.random_int(min=1000, max=9999) for _ in range(5)],
    "Name": [fake.name() for _ in range(5)],
    "Grade": [random.choice(['A', 'B', 'C', 'D', 'E']) for _ in range(5)],
    "Score": [random.randint(30, 100) for _ in range(5)]  # Random scores between 30-100
}

df = pd.DataFrame(student_data)

# Save as CSV and Excel
df.to_csv("students.csv", index=False)
df.to_excel("students.xlsx", sheet_name="Original Data", index=False)

print("Original CSV and Excel files created successfully!")
# Out:
# Original CSV and Excel files created successfully!

# %%
df_csv = pd.read_csv("students.csv")

df_excel = pd.read_excel("students.xlsx", sheet_name="Original Data")

print("Files successfully loaded into DataFrames!")
# Out:
# Files successfully loaded into DataFrames!

# %%
df_csv["Pass/Fail"] = df_csv["Score"].apply(lambda x: "Pass" if x >= 50 else "Fail")
df_excel["Pass/Fail"] = df_excel["Score"].apply(lambda x: "Pass" if x >= 50 else "Fail")

print("Pass/Fail column added successfully!")
# Out:
# Pass/Fail column added successfully!

# %%
df_csv.to_csv("students_modified.csv", index=False)
df_excel.to_excel("students_modified.xlsx", sheet_name="Modified Data", index=False)

print("Modified CSV and Excel files exported successfully!")
# Out:
# Modified CSV and Excel files exported successfully!

# %%
# 2. Create a CSV file and an Excel file with 'City', 'Country', 'Population', and 'Area'. Add 5 
# rows of city data to both files. Upload the files to Jupyter Notebook, then perform an 
# operation to calculate the 'Population Density' (Population / Area) and add it as a new 
# column. Export both files after modification and compare the original and updated files. 
# What new information can you observe in the 'Population Density' column? 

city_data = {
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"],
    "Country": ["USA", "USA", "USA", "USA", "USA"],
    "Population": [8419600, 3980400, 2716000, 2328000, 1690000],  # Sample population data
    "Area": [783.8, 1302, 589, 1625, 1340]  # Sample area in square km
}

df = pd.DataFrame(city_data)

df.to_csv("cities.csv", index=False)
df.to_excel("cities.xlsx", sheet_name="Original Data", index=False)

print("Original CSV and Excel files created successfully!")
# Out:
# Original CSV and Excel files created successfully!

# %%
df_csv = pd.read_csv("cities.csv")

df_excel = pd.read_excel("cities.xlsx", sheet_name="Original Data")

print("Files successfully loaded into DataFrames!")
# Out:
# Files successfully loaded into DataFrames!

# %%
df_csv["Population Density"] = df_csv["Population"] / df_csv["Area"]
df_excel["Population Density"] = df_excel["Population"] / df_excel["Area"]

print("Population Density column added successfully!")
# Out:
# Population Density column added successfully!

# %%
df_csv.to_csv("cities_modified.csv", index=False)
df_excel.to_excel("cities_modified.xlsx", sheet_name="Modified Data", index=False)

print("Modified CSV and Excel files exported successfully!")
# Out:
# Modified CSV and Excel files exported successfully!
